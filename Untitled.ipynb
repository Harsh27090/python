# %%
print('hello')
# Out:
# hello

# %%
def message():
    print('hello! how are you?')

# %%
message()
# Out:
# hello! how are you?

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]
